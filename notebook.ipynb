# %%
from models import *
from flask import g
from run import init_app

test_app = init_app()
if __name__ == "__main__":
    test_app.run(host='0.0.0.0')
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.86.214:5000
# Press CTRL+C to quit

# %%
import pandas as pd

with test_app.app_context():
    
    user_staff_id = 202014
    user_classes = ClassroomSchoolYear.query.filter(ClassroomSchoolYear.teacher_id == user_staff_id)
    user_classes = pd.DataFrame(user_classes)
    grouped_user_classes = user_classes.groupby(['id', 'school_id', 'year_id'])
    
    grouped_user_classes
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\WCSU User\dct_app\venv\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\WCSU User\dct_app\venv\Lib\site-packages\sqlalchemy\engine\base.py:3282, in Engine.raw_connection(self)
#    3261 """Return a "raw" DBAPI connection from the connection pool.
#    3262
#    3263 The returned object is a proxied version of the DBAPI
#    (...)
#    3280
#    3281 """
# -> 3282 return self.pool.connect()
#
# File c:\Users\WCSU User\dct_app\venv\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...
